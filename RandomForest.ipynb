# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
X = np.array([[50,12,0,0],[80,24,1,1],[120,6,1,0],[70,36,0,1],[90,18,1,0]])
y = np.array([1,0,1,0,1])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.33, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100,random_state=42)
model.fit(X_train,y_train)

print("Feature importance", model.feature_importances_)
# Out:
# Feature importance [0.10080645 0.45967742 0.11693548 0.32258065]

# %%
y_pred = model.predict(X_test)
print("Predicted class:", X_test)
# Out:
# Predicted class: [[80 24  1  1]
#  [90 18  1  0]]

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.5
# Confusion Matrix:
#  [[0 1]
#  [0 1]]

# %%
# Plot feature importances
importances = model.feature_importances_
feature_names = ["Monthly Charges", "Tenure", "Internet Service", "Contract Type"]

plt.barh(feature_names, importances)
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance in Random Forest")
plt.show()
